# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path=r'C:\Users\User\Achievement4\Data'

# %%
# Import "orders_products_combined" file
df_ords_prior = pd.read_pickle(os.path.join(path, 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Import "products" file
df_prods = pd.read_csv(os.path.join(path, 'Prepared Data', 'products_clean.csv'))

# %%
#Check the output
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_ords_prior.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  hour_of_day  \
# 0   2539329        1             1                   2            8
# 1   2539329        1             1                   2            8
# 2   2539329        1             1                   2            8
# 3   2539329        1             1                   2            8
# 4   2539329        1             1                   2            8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# 4          0   both

# %%
#Check the output
df_ords_prior.shape
# Out:
# (32434489, 11)

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
# Dropping unnesessary column
df_prods = df_prods.drop(['Unnamed: 0'], axis=1)

# %%
# Checking output
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Dropping unnesessary column in df_ords_prior
df_ords_prior = df_ords_prior.drop(['_merge'], axis=1)

# %%
# Checking ourput
df_ords_prior.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  hour_of_day  \
# 0   2539329        1             1                   2            8
# 1   2539329        1             1                   2            8
# 2   2539329        1             1                   2            8
# 3   2539329        1             1                   2            8
# 4   2539329        1             1                   2            8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
#Merging both dataframes
df_merged_large = df_prods.merge(df_ords_prior, on = 'product_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  hour_of_day  \
# 0   3139998      138            28                   6           11
# 1   1977647      138            30                   6           17
# 2    389851      709             2                   0           21
# 3    652770      764             1                   3           13
# 4   1813452      764             3                   4           17
#
#    days_since_prior_order  first_order  add_to_cart_order  reordered _merge
# ...

# %%
df_merged_large.shape
# Out:
# (32404859, 15)

# %%
#Checking memory usage
df_merged_large.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 15 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   product_id              int64
#  1   product_name            object
#  2   aisle_id                int64
#  3   department_id           int64
#  4   prices                  float64
#  5   order_id                int32
#  6   user_id                 int32
#  7   order_number            int32
#  8   orders_day_of_week      int32
#  9   hour_of_day             int32
#  10  days_since_prior_order  float64
#  11  first_order             bool
#  12  add_to_cart_order       int32
#  13  reordered               int8
#  14  _merge                  category
# dtypes: bool(1), category(1), float64(2), int32(6), int64(3), int8(1), object(1)
# memory usage: 2.3+ GB

# %%
# Change types for ords prods data set in order to reduce the memory used.
df_merged_large['aisle_id'] =df_merged_large['aisle_id'].astype('int32')
df_merged_large['department_id'] =df_merged_large['department_id'].astype('int32')
df_merged_large['product_id'] =df_merged_large['product_id'].astype('int32')

# %%
df_merged_large.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 15 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   product_id              int32
#  1   product_name            object
#  2   aisle_id                int32
#  3   department_id           int32
#  4   prices                  float64
#  5   order_id                int32
#  6   user_id                 int32
#  7   order_number            int32
#  8   orders_day_of_week      int32
#  9   hour_of_day             int32
#  10  days_since_prior_order  float64
#  11  first_order             bool
#  12  add_to_cart_order       int32
#  13  reordered               int8
#  14  _merge                  category
# dtypes: bool(1), category(1), float64(2), int32(9), int8(1), object(1)
# memory usage: 1.9+ GB

# %%
df_merged_large.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  hour_of_day  \
# 0   3139998      138            28                   6           11
# 1   1977647      138            30                   6           17
# 2    389851      709             2                   0           21
# 3    652770      764             1                   3           13
# 4   1813452      764             3                   4           17
#
#    days_since_prior_order  first_order  add_to_cart_order  reordered _merge
# ...

# %%
#Checking numbers of rows and columns
df_merged_large.shape
# Out:
# (32404859, 15)

# %%
df_merged_large[ '_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged_large.shape
# Out:
# (32404859, 15)

# %%
#Exporting the merged file
df_merged_large.to_pickle(os.path.join(path,'Prepared Data', 'orders_products_merge.pkl'))
